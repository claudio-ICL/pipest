# %%
import sys
import os
path_pipest = os.path.abspath('./')
n=0
while (not os.path.basename(path_pipest)=='pipest') and (n<4):
    path_pipest=os.path.dirname(path_pipest)
    n+=1 
if not os.path.basename(path_pipest)=='pipest':
    print("path_pipest not found. Instead: {}".format(path_pipest))
    raise ValueError("path_pipest not found.")
path_models=path_pipest+'/models'    
path_sdhawkes=path_pipest+'/sdhawkes'
path_modelling = path_sdhawkes+'/modelling'
path_resources = path_sdhawkes+'/resources'
path_lobster=path_pipest+'/lobster_for_sdhawkes'
path_lobster_data=path_lobster+'/data'
path_lobster_pyscripts=path_lobster+'/py_scripts'
path_tests = path_pipest+'/tests'
path_saved_tests = path_tests+'/saved_tests'
path_perfmeas=path_tests+'/performance_measurements'
sys.path.append(path_modelling)
sys.path.append(path_resources)
sys.path.append(path_perfmeas)
import numpy as np
import pandas as pd
import pickle
import datetime
import time
import datetime
import timeit
import model as sd_hawkes_model
import plot_tools
# Out:
# openmp.omp_get_max_threads(): 4

# %%
import matplotlib.pyplot as plt

# %%
n_states=[3,5] 
n_events = 4  # number of event types, $d_E$
n_levels = 2
upto_level = 2
time_start=0.0
time_end=time_start+1.0*60 # one minute
model = sd_hawkes_model.SDHawkes(
    number_of_event_types=n_events, list_of_n_states=n_states,
    number_of_lob_levels=n_levels, volume_imbalance_upto_level=upto_level)

# %%
d_E=model.number_of_event_types
d_S=model.number_of_states
print("d_E={}; d_S={}".format(d_E,d_S))
# Out:
# d_E=4; d_S=15

# %% [markdown]
# Assign arbitrary values to the Hawkes parameters $\nu_{e}$, $\alpha_{e',x',e}$ and $\beta_{e',x',e}$

# %%
nus = np.array([0.0,0.0,1.0,1.0],dtype=np.float)
alphas = np.maximum(
    np.concatenate(
        [0.2*np.ones((d_E,d_S,d_E//2),dtype=np.float),np.zeros((d_E,d_S,d_E-d_E//2),dtype=np.float)],
        axis=2),
    np.random.uniform(-0.5,0.5,size=(d_E, d_S, d_E))
)
betas = np.exp(np.minimum(2.0,np.random.uniform(0.0001,4.0,size=(d_E, d_S, d_E))))
model.set_hawkes_parameters(nus,alphas,betas)
# Out:
# Hawkes parameters have been set

# %% [markdown]
# Assign arbitrary values to the transition matrices $\phi_{e}$, for $e=0,\dots,d_E -1$

# %%
phis = model.state_enc.generate_random_transition_prob(n_events=d_E)
model.set_transition_probabilities(phis)
# Out:
# SDHawkes: asymmetry in transition_probabilities = 30.723122237936035
# Transition probabilities have been set

# %% [markdown]
# Assign arbitrary values to the Dirichlet parameters $\gamma_{x}$ for $x = 0,\dots,d_{S}-1$

# %%
gammas = np.random.uniform(low=1.5, high = 5.6,size=(d_S,2*n_levels))
model.set_dirichlet_parameters(gammas)
# Out:
# Producing proposal density for rejection sampling.
# /home/claudio/anaconda3/envs/pipest/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# Dirichlet parameters have been set

# %%
model.simulate(time_start, time_end,
               max_number_of_events=10000,
               add_initial_cond=True,store_results=True, report_full_volumes=False)
# Out:
# Simulation is being performed on the following machine:
#  posix.uname_result(sysname='Linux', nodename='elitebook', release='5.3.0-61-generic', version='#55~18.04.1-Ubuntu SMP Mon Jun 22 16:40:20 UTC 2020', machine='x86_64')
# SDHawkes.simulate: initial conditions have been acknowledged
# I am adding initial conditions on the negative time axis
# simulate: start of initialisation
#    Number of levels in the order book: 2
#    number_of_initial_events=61
#  simulate: labelled_times and count have been initialised.
#  simulate: intensities have been initialised.
#   intensities at start: [0.0037438  0.00570277 1.00203401 1.00116519]
#   intensity_overall at start: 2.01264576887268
# simulate: start of simulation
#   time_start=0.0,  time at start =0.0
#  Simulation terminates. time at end =60.15988515660908,  num_of_event=302
# End of simulation. run_time=0.1 seconds

# %%
model.store_history_of_intensities(density_of_eval_points=5000)

# %%
print(model.simulated_2Dstates.shape)
print(model.simulated_times.shape)
# Out:
# (242, 2)
# (242,)

# %%
model.plot_events_and_states(t_0=28.5,t_1=55.0)

# %%
model.plot_events_and_states()

# %%
model.plot_intensities()

# %%
initial_condition_times=np.array(model.simulated_times,copy=True)
initial_condition_events=np.array(model.simulated_events,copy=True)
initial_condition_states=np.array(model.simulated_states,copy=True)
initial_condition_volumes=np.array(model.simulated_volume,copy=True)

# %%
initial_inventory=10
liquidator_base_rate=1.0
type_of_liquid = 'constant_intensity' #constant_intensity or with_the_market or against_the_market
liquidation_control_type='fraction_of_bid_side' # fraction_of_inventory or fraction_of_bid_side
liquidator_control=0.2
time_start=float(initial_condition_times[-1])
time_end=time_start+0.25*60*60

# %%
model.setup_liquidator(initial_inventory=initial_inventory,
                           time_start=time_start,
                           liquidator_base_rate=liquidator_base_rate,
                           type_of_liquid=type_of_liquid,
                           liquidator_control=liquidator_control)
initial_condition_events+=1
# Out:
# Hawkes parameters have been set
# SDHawkes: asymmetry in transition_probabilities = 35.722662883389
# Transition probabilities have been set
# liquidator.initial_inventory: 10.0
# liquidator.type_of_liquid: constant_intensity
# liquidator.control_type: fraction_of_inventory
# liquidator.control: 0.2
# liquidator.start_time: 59.88982399045031

# %%
model.liquidator.print_info()
# Out:
# liquidator.initial_inventory: 10.0
# liquidator.type_of_liquid: constant_intensity
# liquidator.control_type: fraction_of_inventory
# liquidator.control: 0.2
# liquidator.start_time: 59.88982399045031

# %%
model.simulate_liquidation(
    time_end,
    initial_condition_events=initial_condition_events,
    initial_condition_states=initial_condition_states,
    initial_condition_times=initial_condition_times,
    initial_condition_volumes=initial_condition_volumes,
    verbose=True,
    report_history_of_intensities = False,
    store_results=True
)
# Out:
# Simulation is being performed on the following machine:
#  posix.uname_result(sysname='Linux', nodename='elitebook', release='5.3.0-61-generic', version='#55~18.04.1-Ubuntu SMP Mon Jun 22 16:40:20 UTC 2020', machine='x86_64')
# SDHawkes: simulate_liquidation. initial conditions have been acknowledged
# simulate_liquidation. liquidator_control_type: fraction_of_inventory
#   initial_invetory:10.0
#    number_of_initial_events=242
# initial state:1, initial event:4
# simulate: labelled_times and count have been initialised.
#  labelled_times.shape=(5,15,1000242), count.shape=(5,15)
# simulate: intensities have been initialised.
#   intensities at start: [1.         0.54986871 0.9357732  1.47977052 1.55955812]
#   intensity_overall at start: 5.524970547328688
# start of simulation
#   time_start=59.88982399045031,  time at start =59.88982399045031
# simulate_liquidation. At time 60.586307022634124, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.09551343 0.3259689  0.0998301  0.47868756]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.09551343 0.1259689  0.0998301  0.47868756], new_tot_bid=0.6046564672798163.
# simulate_liquidation. At time 61.18008406566246, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.08970455 0.43796075 0.07934039 0.39299431]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.08970455 0.23796075 0.07934039 0.39299431], new_tot_bid=0.6309550533123691.
# simulate_liquidation. At time 61.85982938531439, liquidator intervenes:
#   previous state=[2 0], previous_volume=[0.3929671  0.12489371 0.45042575 0.03171343]
#   quantity_to_liquidate=0.2, to_subtract=[0.12489371 0.03171343], quantity_liquidated=0.15660714522635025
#   new_state=[0 0], new_volume=[0.3929671  0.         0.45042575 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 61.97999423829778, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.60734491 0.12030616 0.19988138 0.07246755]
#   quantity_to_liquidate=0.2, to_subtract=[0.12030616 0.07246755], quantity_liquidated=0.19277371208410038
#   new_state=[0 0], new_volume=[0.60734491 0.         0.19988138 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 62.02485330841681, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.3505204  0.06219678 0.46740348 0.11987935]
#   quantity_to_liquidate=0.2, to_subtract=[0.06219678 0.11987935], quantity_liquidated=0.1820761240097406
#   new_state=[0 0], new_volume=[0.3505204  0.         0.46740348 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 62.56903338336721, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.34297622 0.17737462 0.35811235 0.12153681]
#   quantity_to_liquidate=0.2, to_subtract=[0.17737462 0.02262538], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.34297622 0.         0.35811235 0.09891143], new_tot_bid=0.0989114282012707.
# simulate_liquidation. At time 63.99312430538866, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.06232959 0.2071832  0.10200514 0.62848207]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.06232959 0.0071832  0.10200514 0.62848207], new_tot_bid=0.63566527020167.
# simulate_liquidation. At time 66.0850804525864, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.15793925 0.76255132 0.01938834 0.06012109]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.15793925 0.56255132 0.01938834 0.06012109], new_tot_bid=0.6226724138536575.
# simulate_liquidation. At time 66.34664043152068, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.10466282 0.54546817 0.04218439 0.30768462]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 4], new_volume=[0.10466282 0.34546817 0.04218439 0.30768462], new_tot_bid=0.6531527923653795.
# simulate_liquidation. At time 68.1003959003225, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.4297584  0.10839195 0.38019087 0.08165879]
#   quantity_to_liquidate=0.2, to_subtract=[0.10839195 0.08165879], quantity_liquidated=0.19005073660487554
#   new_state=[0 0], new_volume=[0.4297584  0.         0.38019087 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 68.13165431847331, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.34602186 0.06558461 0.50332483 0.08506869]
#   quantity_to_liquidate=0.2, to_subtract=[0.06558461 0.08506869], quantity_liquidated=0.1506533023125399
#   new_state=[0 0], new_volume=[0.34602186 0.         0.50332483 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 69.61100480276485, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.52331022 0.10632584 0.31308558 0.05727835]
#   quantity_to_liquidate=0.2, to_subtract=[0.10632584 0.05727835], quantity_liquidated=0.16360419147503708
#   new_state=[0 0], new_volume=[0.52331022 0.         0.31308558 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 70.3017359363474, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.14343794 0.37595335 0.14390689 0.33670182]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.14343794 0.17595335 0.14390689 0.33670182], new_tot_bid=0.5126551665745946.
# simulate_liquidation. At time 70.52738299989669, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.20996867 0.494722   0.12353725 0.17177208]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.20996867 0.294722   0.12353725 0.17177208], new_tot_bid=0.4664940730993148.
# simulate_liquidation. At time 70.60821869845807, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.28201737 0.20093292 0.44132913 0.07572058]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 0], new_volume=[0.28201737 0.00093292 0.44132913 0.07572058], new_tot_bid=0.07665349934987985.
# simulate_liquidation. At time 73.01299287412306, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.12399382 0.48529695 0.10439441 0.28631482]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.12399382 0.28529695 0.10439441 0.28631482], new_tot_bid=0.5716117698130394.
# simulate_liquidation. At time 73.08520058908172, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.1425188  0.54581652 0.07949216 0.23217252]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.1425188  0.34581652 0.07949216 0.23217252], new_tot_bid=0.5779890367217715.
# simulate_liquidation. At time 73.10548777683474, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.10323607 0.33019755 0.13644006 0.43012631]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.10323607 0.13019755 0.13644006 0.43012631], new_tot_bid=0.5603238624328047.
# simulate_liquidation. At time 74.08864503543856, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.15398853 0.22660461 0.33964254 0.27976432]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.15398853 0.02660461 0.33964254 0.27976432], new_tot_bid=0.30636892941457516.
# simulate_liquidation. At time 74.14296655416877, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.25702    0.22973506 0.12387511 0.38936983]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.25702    0.02973506 0.12387511 0.38936983], new_tot_bid=0.41910488769129295.
# simulate_liquidation. At time 75.66812244456456, liquidator intervenes:
#   previous state=[2 0], previous_volume=[0.28544164 0.09578462 0.51994034 0.0988334 ]
#   quantity_to_liquidate=0.2, to_subtract=[0.09578462 0.0988334 ], quantity_liquidated=0.19461801723720362
#   new_state=[0 0], new_volume=[0.28544164 0.         0.51994034 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 76.73273968649359, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.13338962 0.10691366 0.52838838 0.23130834]
#   quantity_to_liquidate=0.2, to_subtract=[0.10691366 0.09308634], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.13338962 0.         0.52838838 0.138222  ], new_tot_bid=0.13822199796781898.
# simulate_liquidation. At time 77.08142413125215, liquidator intervenes:
#   previous state=[2 2], previous_volume=[0.08208854 0.29541594 0.31849288 0.30400265]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.08208854 0.09541594 0.31849288 0.30400265], new_tot_bid=0.3994185823383845.
# simulate_liquidation. At time 78.09402051316029, liquidator intervenes:
#   previous state=[2 2], previous_volume=[0.02170932 0.27186915 0.5478115  0.15861004]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.02170932 0.07186915 0.5478115  0.15861004], new_tot_bid=0.2304791888357457.
# simulate_liquidation. At time 78.93741040099756, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.18145796 0.73447143 0.01484269 0.06922792]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.18145796 0.53447143 0.01484269 0.06922792], new_tot_bid=0.6036993514813003.
# simulate_liquidation. At time 82.04007510452236, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.06420025 0.36323655 0.11698843 0.45557477]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.06420025 0.16323655 0.11698843 0.45557477], new_tot_bid=0.6188113209484861.
# simulate_liquidation. At time 82.53388104050795, liquidator intervenes:
#   previous state=[1 0], previous_volume=[0.28743098 0.08616595 0.52588045 0.10052262]
#   quantity_to_liquidate=0.2, to_subtract=[0.08616595 0.10052262], quantity_liquidated=0.18668856769304468
#   new_state=[0 0], new_volume=[0.28743098 0.         0.52588045 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 85.68472151050622, liquidator intervenes:
#   previous state=[0 2], previous_volume=[0.11212121 0.23884196 0.45667713 0.1923597 ]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.11212121 0.03884196 0.45667713 0.1923597 ], new_tot_bid=0.23120165894254507.
# simulate_liquidation. At time 85.80986893326238, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.10072607 0.39572455 0.02516512 0.47838427]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 4], new_volume=[0.10072607 0.19572455 0.02516512 0.47838427], new_tot_bid=0.6741088109066471.
# simulate_liquidation. At time 86.4194378718345, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.18888815 0.30971451 0.35039813 0.15099921]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.18888815 0.10971451 0.35039813 0.15099921], new_tot_bid=0.26071371950753663.
# simulate_liquidation. At time 88.50189696286199, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.02223841 0.59612822 0.08417615 0.29745723]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 4], new_volume=[0.02223841 0.39612822 0.08417615 0.29745723], new_tot_bid=0.6935854415330417.
# simulate_liquidation. At time 89.0000899913317, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.1452772  0.53473302 0.20653715 0.11345263]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.1452772  0.33473302 0.20653715 0.11345263], new_tot_bid=0.44818565186827103.
# simulate_liquidation. At time 89.3523163801519, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.56247872 0.0399137  0.26622164 0.13138594]
#   quantity_to_liquidate=0.2, to_subtract=[0.0399137  0.13138594], quantity_liquidated=0.1712996374489411
#   new_state=[0 0], new_volume=[0.56247872 0.         0.26622164 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 89.70525470961996, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.67753485 0.11419012 0.12280927 0.08546575]
#   quantity_to_liquidate=0.2, to_subtract=[0.11419012 0.08546575], quantity_liquidated=0.1996558747815022
#   new_state=[0 0], new_volume=[0.67753485 0.         0.12280927 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 92.60579587173072, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.52016378 0.06522237 0.34103348 0.07358038]
#   quantity_to_liquidate=0.2, to_subtract=[0.06522237 0.07358038], quantity_liquidated=0.1388027461927675
#   new_state=[0 0], new_volume=[0.52016378 0.         0.34103348 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 95.14633165506491, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.09240176 0.2648572  0.10252636 0.54021468]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.09240176 0.0648572  0.10252636 0.54021468], new_tot_bid=0.6050718851959476.
# simulate_liquidation. At time 95.15882047387417, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.23762291 0.14573163 0.12656322 0.49008224]
#   quantity_to_liquidate=0.2, to_subtract=[0.14573163 0.05426837], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.23762291 0.         0.12656322 0.43581387], new_tot_bid=0.4358138689974246.
# simulate_liquidation. At time 96.1100648265224, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.20960411 0.16029481 0.04743779 0.58266329]
#   quantity_to_liquidate=0.2, to_subtract=[0.16029481 0.03970519], quantity_liquidated=0.2
#   new_state=[0 3], new_volume=[0.20960411 0.         0.04743779 0.5429581 ], new_tot_bid=0.5429580999030702.
# simulate_liquidation. At time 96.79338773775582, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.30472037 0.10323537 0.0930029  0.49904136]
#   quantity_to_liquidate=0.2, to_subtract=[0.10323537 0.09676463], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.30472037 0.         0.0930029  0.40227673], new_tot_bid=0.4022767252590227.
# simulate_liquidation. At time 97.32533375112858, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.54559885 0.08205964 0.26081425 0.11152726]
#   quantity_to_liquidate=0.2, to_subtract=[0.08205964 0.11152726], quantity_liquidated=0.19358690089885827
#   new_state=[0 0], new_volume=[0.54559885 0.         0.26081425 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 97.78051867734192, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.15643326 0.09453456 0.03958719 0.70944499]
#   quantity_to_liquidate=0.2, to_subtract=[0.09453456 0.10546544], quantity_liquidated=0.2
#   new_state=[0 3], new_volume=[0.15643326 0.         0.03958719 0.60397955], new_tot_bid=0.6039795519448272.
# simulate_liquidation. At time 97.83124733647686, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.17735436 0.16967218 0.2000163  0.45295716]
#   quantity_to_liquidate=0.2, to_subtract=[0.16967218 0.03032782], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.17735436 0.         0.2000163  0.42262934], new_tot_bid=0.42262934108957884.
# simulate_liquidation. At time 99.04661722723799, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.37917194 0.18271938 0.28369073 0.15441795]
#   quantity_to_liquidate=0.2, to_subtract=[0.18271938 0.01728062], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.37917194 0.         0.28369073 0.13713733], new_tot_bid=0.13713733061396732.
# simulate_liquidation. At time 99.94261228455925, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.15118833 0.20186775 0.25995238 0.38699155]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.15118833 0.00186775 0.25995238 0.38699155], new_tot_bid=0.38885929216186943.
# simulate_liquidation. At time 101.25222470131162, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.22962457 0.17424288 0.12131314 0.47481942]
#   quantity_to_liquidate=0.2, to_subtract=[0.17424288 0.02575712], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.22962457 0.         0.12131314 0.4490623 ], new_tot_bid=0.44906229759563043.
# simulate_liquidation. At time 103.24910339137173, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.24996226 0.31284675 0.3813403  0.0558507 ]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.24996226 0.11284675 0.3813403  0.0558507 ], new_tot_bid=0.16869744535886436.
# simulate_liquidation. At time 103.27248928419758, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.19953049 0.2066163  0.43690308 0.15695014]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.19953049 0.0066163  0.43690308 0.15695014], new_tot_bid=0.16356643542459282.
# simulate_liquidation. At time 103.34658687357364, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.22087278 0.16877097 0.11907328 0.49128296]
#   quantity_to_liquidate=0.2, to_subtract=[0.16877097 0.03122903], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.22087278 0.         0.11907328 0.46005393], new_tot_bid=0.46005393371312353.
# simulate_liquidation. At time 104.25035923534722, liquidator intervenes:
#   previous state=[2 0], previous_volume=[0.38392175 0.04069973 0.53429429 0.04108422]
#   quantity_to_liquidate=0.2, to_subtract=[0.04069973 0.04108422], quantity_liquidated=0.08178395475228378
#   new_state=[0 0], new_volume=[0.38392175 0.         0.53429429 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 105.50490785678986, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.13763284 0.46727738 0.20578441 0.18930538]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.13763284 0.26727738 0.20578441 0.18930538], new_tot_bid=0.4565827535686336.
# simulate_liquidation. At time 106.21693240628504, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.20404219 0.04034493 0.4443556  0.31125728]
#   quantity_to_liquidate=0.2, to_subtract=[0.04034493 0.15965507], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.20404219 0.         0.4443556  0.15160221], new_tot_bid=0.15160220871130264.
# simulate_liquidation. At time 107.89499922582765, liquidator intervenes:
#   previous state=[2 1], previous_volume=[0.16214027 0.15477186 0.47745733 0.20563055]
#   quantity_to_liquidate=0.19779908928275247, to_subtract=[0.15477186 0.04302723], quantity_liquidated=0.19779908928275247
#   new_state=[0 1], new_volume=[0.16214027 0.         0.47745733 0.16260332], new_tot_bid=0.1626033186780666.
# Simulation terminates. time at end =959.9505999913491,  num_of_event=4937
#  liquidation terminates at time: 107.89499922582765
# End of simulation: run_time=2.8 seconds
# Warning: Transition probabilities from state 9 when events of type 0 occur cannot be estimated because events of this type never occur this state

# %%
model.liquidator.print_info()
# Out:
# liquidator.initial_inventory: 10.0
# liquidator.type_of_liquid: constant_intensity
# liquidator.control_type: fraction_of_inventory
# liquidator.control: 0.2
# liquidator.start_time: 59.88982399045031
# liquidator.termination_time: 107.89499922582765

# %%
model.make_start_liquid_origin_of_times(delete_negative_times=False)
# Out:
# SDHawkes: liquidator.start_time has been set as origin of times

# %%
model.create_impact_profile(delete_negative_times=False,
                            produce_weakly_defl_pp=False,
                            maxiter=10, num_init_guesses=1)
# Out:
# SDHawkes: liquidator.start_time has been set as origin of times
#
# SDHawkes:  "liquidator.impact" has been initialised

# %%
model.liquidator.impact.store_bm_impact()

# %%
model.store_price_trajectory()

# %%
plt.plot(model.simulated_price[:,0], model.simulated_price[:,1])

# %%
model.store_history_of_intensities()

# %%
model.plot_bm_impact_profile(time_start=-5.0, time_end=80.0)

# %%
model.plot_events_and_states(t_0=-50.5,t_1=105.0, first_event_index=0)
