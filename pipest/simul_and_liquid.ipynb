# %%
import sys
import os
path_pipest = os.path.abspath('./')
n=0
while (not os.path.basename(path_pipest)=='pipest') and (n<4):
    path_pipest=os.path.dirname(path_pipest)
    n+=1 
if not os.path.basename(path_pipest)=='pipest':
    print("path_pipest not found. Instead: {}".format(path_pipest))
    raise ValueError("path_pipest not found.")
path_models=path_pipest+'/models'    
path_sdhawkes=path_pipest+'/sdhawkes'
path_modelling = path_sdhawkes+'/modelling'
path_resources = path_sdhawkes+'/resources'
path_lobster=path_pipest+'/lobster_for_sdhawkes'
path_lobster_data=path_lobster+'/data'
path_lobster_pyscripts=path_lobster+'/py_scripts'
path_tests = path_pipest+'/tests'
path_saved_tests = path_tests+'/saved_tests'
path_perfmeas=path_tests+'/performance_measurements'
sys.path.append(path_modelling)
sys.path.append(path_resources)
sys.path.append(path_perfmeas)
import numpy as np
import pandas as pd
import pickle
import datetime
import time
import datetime
import timeit
import model as sd_hawkes_model
import plot_tools
# Out:
# openmp.omp_get_max_threads(): 4
# openmp.omp_get_max_threads(): 4

# %%
n_states=[3,5] 
n_events = 4  # number of event types, $d_E$
n_levels = 2
upto_level = 2
time_start=0.0
time_end=time_start+1.0*60 # one minute
model = sd_hawkes_model.SDHawkes(
    number_of_event_types=n_events, list_of_n_states=n_states,
    number_of_lob_levels=n_levels, volume_imbalance_upto_level=upto_level)

# %%
d_E=model.number_of_event_types
d_S=model.number_of_states
print("d_E={}; d_S={}".format(d_E,d_S))
# Out:
# d_E=4; d_S=15

# %% [markdown]
# Assign arbitrary values to the Hawkes parameters $\nu_{e}$, $\alpha_{e',x',e}$ and $\beta_{e',x',e}$

# %%
nus = np.array([0.0,0.0,1.0,1.0],dtype=np.float)
alphas = np.maximum(
    np.concatenate(
        [0.2*np.ones((d_E,d_S,d_E//2),dtype=np.float),np.zeros((d_E,d_S,d_E-d_E//2),dtype=np.float)],
        axis=2),
    np.random.uniform(-0.5,0.5,size=(d_E, d_S, d_E))
)
betas = np.exp(np.minimum(2.0,np.random.uniform(0.0001,4.0,size=(d_E, d_S, d_E))))
model.set_hawkes_parameters(nus,alphas,betas)
# Out:
# Hawkes parameters have been set

# %% [markdown]
# Assign arbitrary values to the transition matrices $\phi_{e}$, for $e=0,\dots,d_E -1$

# %%
phis = model.state_enc.generate_random_transition_prob(n_events=d_E)
model.set_transition_probabilities(phis)
# Out:
# SDHawkes: asymmetry in transition_probabilities = 21.466712443922155
# Transition probabilities have been set

# %% [markdown]
# Assign arbitrary values to the Dirichlet parameters $\gamma_{x}$ for $x = 0,\dots,d_{S}-1$

# %%
gammas = np.random.uniform(low=1.5, high = 5.6,size=(d_S,2*n_levels))
model.set_dirichlet_parameters(gammas)
# Out:
# Producing proposal density for rejection sampling.
# /home/claudio/anaconda3/envs/pipest/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
# Dirichlet parameters have been set

# %%
model.simulate(time_start, time_end,
               max_number_of_events=10000,
               add_initial_cond=True,store_results=True, report_full_volumes=False)
# Out:
# Simulation is being performed on the following machine:
#  posix.uname_result(sysname='Linux', nodename='elitebook', release='5.3.0-61-generic', version='#55~18.04.1-Ubuntu SMP Mon Jun 22 16:40:20 UTC 2020', machine='x86_64')
# SDHawkes.simulate: initial conditions have been acknowledged
# I am adding initial conditions on the negative time axis
# simulate: start of initialisation
#    Number of levels in the order book: 2
#    number_of_initial_events=61
#  simulate: labelled_times and count have been initialised.
#  simulate: intensities have been initialised.
#   intensities at start: [0.00110188 0.00527993 1.00000225 1.00013732]
#   intensity_overall at start: 2.006521377476047
# simulate: start of simulation
#   time_start=0.0,  time at start =0.0
#  Simulation terminates. time at end =60.29960660156952,  num_of_event=232
# End of simulation. run_time=0.1 seconds

# %%
model.store_history_of_intensities(density_of_eval_points=5000)

# %%
model.plot_events_and_states(t_0=28.5,t_1=55.0)

# %%
model.plot_events_and_states()

# %%
model.plot_intensities()

# %%
initial_condition_times=np.array(model.simulated_times,copy=True)
initial_condition_events=np.array(model.simulated_events,copy=True)
initial_condition_states=np.array(model.simulated_states,copy=True)
initial_condition_volumes=np.array(model.simulated_volume,copy=True)

# %%
initial_inventory=10
liquidator_base_rate=np.amin(model.base_rates)
liquidation_strategy='fraction_of_bid_side' # constant_rate or fraction_of_bid_side
liquidator_control=0.2
time_start=float(initial_condition_times[-1])
time_end=time_start+1.0*60*60

# %%
model.introduce_liquidator(initial_inventory=initial_inventory,
                                 time_start=time_start,
                                 liquidator_base_rate=liquidator_base_rate,
                                 liquidator_control=liquidator_control)
initial_condition_events+=1
time_liquidation_starts=model.liquidator.time_start
print(model.liquidator.initial_inventory)
print(model.liquidator.base_rate)
print(model.liquidator.control_type)
# Out:
# SDHawkes.introduce_liquidator:
#   type_of_liquid:with_the_market, without self excitation.
#  new number of event types= 5
# 10.0
# 0.0
# fraction_of_inventory

# %%
model.simulate_liquidation(
    time_end,
    initial_condition_events=initial_condition_events,
    initial_condition_states=initial_condition_states,
    initial_condition_times=initial_condition_times,
    initial_condition_volumes=initial_condition_volumes,
    verbose=True,
    report_history_of_intensities = False,
    store_results=True
)
# Out:
# Simulation is being performed on the following machine:
#  posix.uname_result(sysname='Linux', nodename='elitebook', release='5.3.0-61-generic', version='#55~18.04.1-Ubuntu SMP Mon Jun 22 16:40:20 UTC 2020', machine='x86_64')
# SDHawkes: simulate_liquidation. initial conditions have been acknowledged
# simulate_liquidation. liquidator_control_type: fraction_of_inventory
#   initial_invetory:10.0
#    number_of_initial_events=172
# initial state:4, initial event:4
# simulate: labelled_times and count have been initialised.
#  labelled_times.shape=(5,15,1000172), count.shape=(5,15)
# simulate: intensities have been initialised.
#   intensities at start: [0.1914213  0.1914213  0.24146131 1.01185756 1.02001541]
#   intensity_overall at start: 2.6561768775885404
# start of simulation
#   time_start=59.52323882014449,  time at start =59.52323882014449
# simulate_liquidation. At time 66.9581448957299, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.22762242 0.10366104 0.59112499 0.07759155]
#   quantity_to_liquidate=0.2, to_subtract=[0.10366104 0.07759155], quantity_liquidated=0.1812525833538376
#   new_state=[0 0], new_volume=[0.22762242 0.         0.59112499 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 73.59013889394545, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.15338354 0.59262728 0.03504669 0.21894249]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.15338354 0.39262728 0.03504669 0.21894249], new_tot_bid=0.6115697718468392.
# simulate_liquidation. At time 74.22815984849093, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.14707679 0.57148541 0.04124079 0.24019701]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.14707679 0.37148541 0.04124079 0.24019701], new_tot_bid=0.6116824228779469.
# simulate_liquidation. At time 74.57161885448689, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.51333355 0.23729783 0.09148785 0.15788078]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.51333355 0.03729783 0.09148785 0.15788078], new_tot_bid=0.19517860684113802.
# simulate_liquidation. At time 75.920330865102, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.00711092 0.38213629 0.17487855 0.43587425]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.00711092 0.18213629 0.17487855 0.43587425], new_tot_bid=0.6180105348230767.
# simulate_liquidation. At time 77.57537779978101, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.59275952 0.05568841 0.05885133 0.29270074]
#   quantity_to_liquidate=0.2, to_subtract=[0.05568841 0.14431159], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.59275952 0.         0.05885133 0.14838915], new_tot_bid=0.14838915018769952.
# simulate_liquidation. At time 77.6545033220548, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.11982016 0.13758809 0.10230044 0.64029132]
#   quantity_to_liquidate=0.2, to_subtract=[0.13758809 0.06241191], quantity_liquidated=0.2
#   new_state=[0 3], new_volume=[0.11982016 0.         0.10230044 0.57787941], new_tot_bid=0.5778794063893036.
# simulate_liquidation. At time 77.79804800172305, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.31814302 0.08058269 0.34702298 0.2542513 ]
#   quantity_to_liquidate=0.2, to_subtract=[0.08058269 0.11941731], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.31814302 0.         0.34702298 0.134834  ], new_tot_bid=0.13483399901717802.
# simulate_liquidation. At time 85.29962460804681, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.13815345 0.23666501 0.04904836 0.57613318]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.13815345 0.03666501 0.04904836 0.57613318], new_tot_bid=0.6127981969812744.
# simulate_liquidation. At time 89.96851584384778, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.06594859 0.40836474 0.03040224 0.49528443]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 4], new_volume=[0.06594859 0.20836474 0.03040224 0.49528443], new_tot_bid=0.7036491749366225.
# simulate_liquidation. At time 92.14294154570011, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.30371808 0.06687588 0.54556104 0.083845  ]
#   quantity_to_liquidate=0.2, to_subtract=[0.06687588 0.083845  ], quantity_liquidated=0.15072087949485513
#   new_state=[0 0], new_volume=[0.30371808 0.         0.54556104 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 92.17258149555961, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.12779333 0.04564609 0.67303804 0.15352255]
#   quantity_to_liquidate=0.2, to_subtract=[0.04564609 0.15352255], quantity_liquidated=0.1991686389533625
#   new_state=[0 0], new_volume=[0.12779333 0.         0.67303804 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 92.85482322331961, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.14362907 0.32750709 0.24665559 0.28220824]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.14362907 0.12750709 0.24665559 0.28220824], new_tot_bid=0.4097153314282434.
# simulate_liquidation. At time 103.64407088608411, liquidator intervenes:
#   previous state=[0 2], previous_volume=[0.35349352 0.16682824 0.07163409 0.40804415]
#   quantity_to_liquidate=0.2, to_subtract=[0.16682824 0.03317176], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.35349352 0.         0.07163409 0.37487239], new_tot_bid=0.37487238954276886.
# simulate_liquidation. At time 104.05717135822698, liquidator intervenes:
#   previous state=[0 4], previous_volume=[0.03293729 0.30913638 0.15271863 0.50520771]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.03293729 0.10913638 0.15271863 0.50520771], new_tot_bid=0.6143440856627427.
# simulate_liquidation. At time 105.04317020520668, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.45372568 0.07391434 0.22819089 0.24416909]
#   quantity_to_liquidate=0.2, to_subtract=[0.07391434 0.12608566], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.45372568 0.         0.22819089 0.11808343], new_tot_bid=0.11808342931102431.
# simulate_liquidation. At time 109.07557477521677, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.16681411 0.01906058 0.70985202 0.10427329]
#   quantity_to_liquidate=0.2, to_subtract=[0.01906058 0.10427329], quantity_liquidated=0.1233338701158799
#   new_state=[0 0], new_volume=[0.16681411 0.         0.70985202 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 109.24855733552359, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.22588608 0.01586798 0.57463009 0.18361586]
#   quantity_to_liquidate=0.2, to_subtract=[0.01586798 0.18361586], quantity_liquidated=0.19948383111545728
#   new_state=[0 0], new_volume=[0.22588608 0.         0.57463009 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 110.6927858485969, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.19534277 0.16928061 0.36189861 0.27347801]
#   quantity_to_liquidate=0.2, to_subtract=[0.16928061 0.03071939], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.19534277 0.         0.36189861 0.24275862], new_tot_bid=0.24275861717957614.
# simulate_liquidation. At time 111.04938329777002, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.11116889 0.41469757 0.13050324 0.34363029]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.11116889 0.21469757 0.13050324 0.34363029], new_tot_bid=0.5583278652418033.
# simulate_liquidation. At time 117.09148649112208, liquidator intervenes:
#   previous state=[2 2], previous_volume=[0.13358888 0.49698404 0.28162073 0.08780634]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.13358888 0.29698404 0.28162073 0.08780634], new_tot_bid=0.38479038562046475.
# simulate_liquidation. At time 120.62587419142403, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.11993549 0.4685076  0.22241097 0.18914595]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.11993549 0.2685076  0.22241097 0.18914595], new_tot_bid=0.45765354273027387.
# simulate_liquidation. At time 123.5027388426697, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.35640072 0.13488777 0.26614874 0.24256277]
#   quantity_to_liquidate=0.2, to_subtract=[0.13488777 0.06511223], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.35640072 0.         0.26614874 0.17745054], new_tot_bid=0.1774505378327009.
# simulate_liquidation. At time 123.68773668878771, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.33850864 0.05857921 0.37691526 0.22599689]
#   quantity_to_liquidate=0.2, to_subtract=[0.05857921 0.14142079], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.33850864 0.         0.37691526 0.0845761 ], new_tot_bid=0.08457609941035257.
# simulate_liquidation. At time 124.19962605035987, liquidator intervenes:
#   previous state=[2 0], previous_volume=[0.29534449 0.10720377 0.51676015 0.08069159]
#   quantity_to_liquidate=0.2, to_subtract=[0.10720377 0.08069159], quantity_liquidated=0.18789536619109837
#   new_state=[0 0], new_volume=[0.29534449 0.         0.51676015 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 124.42066284393975, liquidator intervenes:
#   previous state=[1 0], previous_volume=[0.14486673 0.06139419 0.6553823  0.13835678]
#   quantity_to_liquidate=0.2, to_subtract=[0.06139419 0.13835678], quantity_liquidated=0.19975096973917153
#   new_state=[0 0], new_volume=[0.14486673 0.         0.6553823  0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 125.76875304782989, liquidator intervenes:
#   previous state=[2 0], previous_volume=[0.17966508 0.14292    0.64268899 0.03472593]
#   quantity_to_liquidate=0.2, to_subtract=[0.14292    0.03472593], quantity_liquidated=0.17764592978523686
#   new_state=[0 0], new_volume=[0.17966508 0.         0.64268899 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 126.23771249594073, liquidator intervenes:
#   previous state=[0 0], previous_volume=[0.3187671  0.04910192 0.50861214 0.12351884]
#   quantity_to_liquidate=0.2, to_subtract=[0.04910192 0.12351884], quantity_liquidated=0.1726207627979522
#   new_state=[0 0], new_volume=[0.3187671  0.         0.50861214 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 127.6006240357408, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.18166874 0.41635902 0.19402763 0.20794461]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.18166874 0.21635902 0.19402763 0.20794461], new_tot_bid=0.4243036322633307.
# simulate_liquidation. At time 127.85717887792181, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.1351016  0.03689181 0.08456963 0.74343696]
#   quantity_to_liquidate=0.2, to_subtract=[0.03689181 0.16310819], quantity_liquidated=0.2
#   new_state=[0 3], new_volume=[0.1351016  0.         0.08456963 0.58032877], new_tot_bid=0.5803287715768799.
# simulate_liquidation. At time 128.96337216968527, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.14634705 0.50339181 0.03893201 0.31132913]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.14634705 0.30339181 0.03893201 0.31132913], new_tot_bid=0.6147209399538272.
# simulate_liquidation. At time 129.51052489969422, liquidator intervenes:
#   previous state=[0 2], previous_volume=[0.14387338 0.1849444  0.37102049 0.30016172]
#   quantity_to_liquidate=0.2, to_subtract=[0.1849444 0.0150556], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.14387338 0.         0.37102049 0.28510613], new_tot_bid=0.2851061270282216.
# simulate_liquidation. At time 130.00950447574283, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.15797665 0.17171403 0.22737098 0.44293835]
#   quantity_to_liquidate=0.2, to_subtract=[0.17171403 0.02828597], quantity_liquidated=0.2
#   new_state=[0 2], new_volume=[0.15797665 0.         0.22737098 0.41465238], new_tot_bid=0.41465237614905626.
# simulate_liquidation. At time 135.86875473178898, liquidator intervenes:
#   previous state=[0 2], previous_volume=[0.22671186 0.15930712 0.3206761  0.29330492]
#   quantity_to_liquidate=0.2, to_subtract=[0.15930712 0.04069288], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.22671186 0.         0.3206761  0.25261203], new_tot_bid=0.2526120332661117.
# simulate_liquidation. At time 136.15489422396095, liquidator intervenes:
#   previous state=[0 1], previous_volume=[0.5497116  0.20181124 0.10968043 0.13879672]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 0], new_volume=[0.5497116  0.00181124 0.10968043 0.13879672], new_tot_bid=0.14060796493235342.
# simulate_liquidation. At time 137.60316697600618, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.03363437 0.37686381 0.31789252 0.27160929]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.03363437 0.17686381 0.31789252 0.27160929], new_tot_bid=0.4484731034412787.
# simulate_liquidation. At time 140.6643179418856, liquidator intervenes:
#   previous state=[2 2], previous_volume=[0.27370636 0.30098297 0.19590006 0.22941061]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.27370636 0.10098297 0.19590006 0.22941061], new_tot_bid=0.3303935761443487.
# simulate_liquidation. At time 142.90284843650392, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.49101553 0.04917684 0.1456607  0.31414693]
#   quantity_to_liquidate=0.2, to_subtract=[0.04917684 0.15082316], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.49101553 0.         0.1456607  0.16332377], new_tot_bid=0.16332377169951998.
# simulate_liquidation. At time 143.4844029934716, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.52897075 0.09325509 0.1137922  0.26398197]
#   quantity_to_liquidate=0.2, to_subtract=[0.09325509 0.10674491], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.52897075 0.         0.1137922  0.15723706], new_tot_bid=0.15723705753621453.
# simulate_liquidation. At time 146.20416653372325, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.1527434  0.13998859 0.40169157 0.30557645]
#   quantity_to_liquidate=0.2, to_subtract=[0.13998859 0.06001141], quantity_liquidated=0.2
#   new_state=[0 1], new_volume=[0.1527434  0.         0.40169157 0.24556504], new_tot_bid=0.24556503514729003.
# simulate_liquidation. At time 147.95815587071564, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.28935248 0.28892757 0.10175614 0.31996381]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.28935248 0.08892757 0.10175614 0.31996381], new_tot_bid=0.4088913837096292.
# simulate_liquidation. At time 148.12501419364435, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.1422965  0.33365317 0.06334092 0.46070941]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.1422965  0.13365317 0.06334092 0.46070941], new_tot_bid=0.5943625806145586.
# simulate_liquidation. At time 149.46784338138443, liquidator intervenes:
#   previous state=[2 1], previous_volume=[0.52611668 0.14770636 0.1616975  0.16447946]
#   quantity_to_liquidate=0.2, to_subtract=[0.14770636 0.05229364], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.52611668 0.         0.1616975  0.11218582], new_tot_bid=0.11218581797829544.
# simulate_liquidation. At time 150.5253879354687, liquidator intervenes:
#   previous state=[1 4], previous_volume=[0.10061213 0.33576081 0.0650357  0.49859136]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.10061213 0.13576081 0.0650357  0.49859136], new_tot_bid=0.6343521691833951.
# simulate_liquidation. At time 152.07610862019555, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.14906317 0.45428168 0.1429432  0.25371196]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 3], new_volume=[0.14906317 0.25428168 0.1429432  0.25371196], new_tot_bid=0.5079936353658224.
# simulate_liquidation. At time 156.7958180434967, liquidator intervenes:
#   previous state=[1 0], previous_volume=[0.23775659 0.05313571 0.56406643 0.14504127]
#   quantity_to_liquidate=0.2, to_subtract=[0.05313571 0.14504127], quantity_liquidated=0.19817698306878115
#   new_state=[0 0], new_volume=[0.23775659 0.         0.56406643 0.        ], new_tot_bid=0.0.
# simulate_liquidation. At time 158.08930205893327, liquidator intervenes:
#   previous state=[0 3], previous_volume=[0.06515528 0.47553429 0.26908962 0.19022081]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.06515528 0.27553429 0.26908962 0.19022081], new_tot_bid=0.46575509669573967.
# simulate_liquidation. At time 158.4517497095792, liquidator intervenes:
#   previous state=[1 3], previous_volume=[0.20586501 0.23124205 0.16645786 0.39643508]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.20586501 0.03124205 0.16645786 0.39643508], new_tot_bid=0.42767713059051216.
# simulate_liquidation. At time 160.38811665766758, liquidator intervenes:
#   previous state=[2 3], previous_volume=[0.16831225 0.5081708  0.19536019 0.12815676]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 2], new_volume=[0.16831225 0.3081708  0.19536019 0.12815676], new_tot_bid=0.4363275624850802.
# simulate_liquidation. At time 160.8510025797775, liquidator intervenes:
#   previous state=[1 2], previous_volume=[0.42981089 0.20343608 0.08120267 0.28555036]
#   quantity_to_liquidate=0.2, to_subtract=[0.2 0. ], quantity_liquidated=0.2
#   new_state=[1 1], new_volume=[0.42981089 0.00343608 0.08120267 0.28555036], new_tot_bid=0.28898643895090187.
# simulate_liquidation. At time 161.6921232986765, liquidator intervenes:
#   previous state=[1 1], previous_volume=[0.63431789 0.09380328 0.06619089 0.20568795]
#   quantity_to_liquidate=0.2, to_subtract=[0.09380328 0.10619672], quantity_liquidated=0.2
#   new_state=[0 0], new_volume=[0.63431789 0.         0.06619089 0.09949122], new_tot_bid=0.09949122396257203.
# simulate_liquidation. At time 162.09420656053518, liquidator intervenes:
#   previous state=[2 4], previous_volume=[0.15805449 0.41581453 0.02398532 0.40214566]
#   quantity_to_liquidate=0.009950185384370924, to_subtract=[0.00995019 0.        ], quantity_liquidated=0.009950185384370924
#   new_state=[1 4], new_volume=[0.15805449 0.40586434 0.02398532 0.40214566], new_tot_bid=0.8080100065018887.
# Simulation terminates. time at end =3659.636394989685,  num_of_event=13790
#  liquidation terminates at time: 162.09420656053518
# End of simulation: run_time=20.2 seconds
